# %%
import urllib.request

html = urllib.request.urlopen("https://www.guru99.com/accessing-internet-data-with-python.html")
text = html.read()
plaintext = text.decode('utf8')
links = re.findall("href=[\"\'](.*?)[\"\']", plaintext)
print(links[:])
print(len(links))
# Out:
# ['https://gmpg.org/xfn/11', 'https://www.guru99.com/wp-content/cache/min/1/78aa89acc0943473e46608b3547f5894.css', 'https://www.guru99.com/accessing-internet-data-with-python.html', '//cdn.guru99.com', '//cdn.guru99.com', 'https://www.guru99.com/wp-json/', 'https://www.guru99.com/wp-json/wp/v2/posts/762', 'https://www.guru99.com/xmlrpc.php?rsd', 'https://www.guru99.com/wp-includes/wlwmanifest.xml', 'https://www.guru99.com/?p=762', 'https://www.guru99.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.guru99.com%2Faccessing-internet-data-with-python.html', 'https://www.guru99.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.guru99.com%2Faccessing-internet-data-with-python.html&#038;format=xml', 'https://www.guru99.com/xmlrpc.php', 'https://www.guru99.com/wp-content/fonts/source-sans-pro/6xK3dSBYKcSV-LCoeQqfX1RYOo3qOK7l.woff2', 'https://cdn.guru99.com/images/Favicon_new150-x150-120x120.png', 'https://cdn.guru99.com/images/Favicon_new150-x150.png', 'https://cdn.guru99.com/images/Favico
# ...
