# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
airbnb=pd.read_csv("C:\\Users\\patel\\Desktop\\Airbnb Data\\AB_US_2020.csv")

# %%
airbnb.shape
# Out:
# (226030, 17)

# %%
dataset_columns = list(airbnb.columns)
dataset_columns
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'city']

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226030 entries, 0 to 226029
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              226030 non-null  int64
#  1   name                            226002 non-null  object
#  2   host_id                         226030 non-null  int64
#  3   host_name                       225997 non-null  object
#  4   neighbourhood_group             110185 non-null  object
#  5   neighbourhood                   226030 non-null  object
#  6   latitude                        226030 non-null  float64
#  7   longitude                       226030 non-null  float64
#  8   room_type                       226030 non-null  object
#  9   price                           226030 non-null  int64
#  10  minimum_nights                  226030 non-null  int64
#  11  number_of_reviews               226030 non-null  int64
# ...

# %%
airbnb.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# city                               object
# dtype: object

# %%
airbnb.isnull().sum()
# Out:
# id                                     0
# name                                  28
# host_id                                0
# host_name                             33
# neighbourhood_group               115845
# neighbourhood                          0
# latitude                               0
# longitude                              0
# room_type                              0
# price                                  0
# minimum_nights                         0
# number_of_reviews                      0
# last_review                        48602
# reviews_per_month                  48602
# calculated_host_listings_count         0
# availability_365                       0
# city                                   0
# dtype: int64

# %%
airbnb.last_review
# Out:
# 0         16/02/20
# 1         07/09/20
# 2         30/11/19
# 3         22/09/20
# 4         19/10/15
#             ...
# 226025         NaN
# 226026         NaN
# 226027         NaN
# 226028         NaN
# 226029         NaN
# Name: last_review, Length: 226030, dtype: object

# %%
airbnb.last_review.fillna(method="ffill",inplace=True)

# %%
airbnb.last_review
# Out:
# 0         16/02/20
# 1         07/09/20
# 2         30/11/19
# 3         22/09/20
# 4         19/10/15
#             ...
# 226025    18/09/20
# 226026    18/09/20
# 226027    18/09/20
# 226028    18/09/20
# 226029    18/09/20
# Name: last_review, Length: 226030, dtype: object

# %%
print("last_review :- ",airbnb.last_review.isnull().sum())
# Out:
# last_review :-  0

# %%
sns.set(font_scale=2.5)
plt.figure(figsize=(30,20))
sns.heatmap(airbnb.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.set(font_scale=1.5)
fig = plt.figure(figsize=(15,10))
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = list(airbnb.city.unique())
students =list(airbnb.city.value_counts())
ax.pie(students, labels = langs,autopct='%1.2f%%')
plt.show()

# %%
airbnb.head()
# Out:
#        id                                               name  host_id  \
# 0   38585    Charming Victorian home - twin beds + breakfast   165529
# 1   80905                                   French Chic Loft   427027
# 2  108061  Walk to stores/parks/downtown. Fenced yard/Pet...   320564
# 3  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 4  160594                                Historic Grove Park   769252
#
#    host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0    Evelyne                 NaN         28804  35.65146  -82.62792
# 1    Celeste                 NaN         28801  35.59779  -82.55540
# 2       Lisa                 NaN         28801  35.60670  -82.55563
# 3    BonPaul                 NaN         28806  35.57864  -82.59578
# 4  Elizabeth                 NaN         28801  35.61442  -82.54127
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Out:
# (177428, 13)

# %%
# Out:
#     host_id neighbourhood  latitude  longitude        room_type  price  \
# 0    165529         28804  35.65146  -82.62792     Private room     60
# 1    427027         28801  35.59779  -82.55540  Entire home/apt    470
# 2    320564         28801  35.60670  -82.55563  Entire home/apt     75
# 3    746673         28806  35.57864  -82.59578  Entire home/apt     90
# 4    769252         28801  35.61442  -82.54127     Private room    125
# 5   1029919         28804  35.61856  -82.55276  Entire home/apt    134
# 6   1098412         28806  35.58345  -82.59713     Private room     48
# 7   1292070         28805  35.59635  -82.50655     Private room     65
# 8   1362726         28805  35.61929  -82.48114  Entire home/apt     71
# 9   1501882         28803  35.55537  -82.53539  Entire home/apt     50
# 10  1566145         28804  35.64453  -82.52586  Entire home/apt    289
# 11  1788071         28806  35.58217  -82.59997  Entire home/apt     78
# ...

# %%
# Out:
# Text(0.5, 1.0, 'Neighbourhood')

# %%
# Out:
# Text(0.5, 1.0, 'Restaurants delivering online or Not')

# %%
# plt.figure(figsize=(100,100))
# ax = sns.boxplot(data=airbnb, x='neighbourhood',y='availability_365',palette='plasma')

# %%
# Out:
#          room_type  price  minimum_nights last_review  \
# 0     Private room     60               1    16/02/20
# 1  Entire home/apt    470               1    07/09/20
# 2  Entire home/apt     75              30    30/11/19
# 3  Entire home/apt     90               1    22/09/20
# 4     Private room    125              30    19/10/15
#
#    calculated_host_listings_count  availability_365       city
# 0                               1                 0  Asheville
# 1                              11               288  Asheville
# 2                               2               298  Asheville
# 3                               5                 0  Asheville
# 4                               1                 0  Asheville

# %%
# Out:
# Index(['room_type', 'price', 'minimum_nights', 'last_review',
#        'calculated_host_listings_count', 'availability_365', 'city'],
#       dtype='object')
